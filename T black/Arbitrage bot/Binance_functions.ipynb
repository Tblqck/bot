# %%
import requests
import json
from datetime import datetime, timedelta
from exchange_markets import exchange_market_lists

def fetch_present_data_and_save(asset):
    base_url = 'https://api.binance.com/api/v3/ticker/24hr'
    trading_pair = exchange_market_lists['Binance'][asset]
    params = {'symbol': trading_pair}
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        present_data = {
            'exchange': 'Binance',
            'asset': asset,
            'trading_pair': trading_pair,
            'price': data['lastPrice'],
            'volume': data['quoteVolume'],
            'liquidity_score': None,
            'fetch_time': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }

        try:
            # Load existing data from JSON file
            with open('market_data.json', 'r') as market_data_file:
                existing_data = json.load(market_data_file)
        except (FileNotFoundError, json.JSONDecodeError):
            existing_data = []

        # Append the new present data to existing data
        existing_data.append(present_data)

        # Save the updated data to JSON file
        with open('market_data.json', 'w') as market_data_file:
            json.dump(existing_data, market_data_file, indent=4)
            print(f'{asset} present data appended to market_data.json')
    else:
        print('Error occurred. Status Code:', response.status_code)

if __name__ == '__main__':
    asset_to_fetch = 'MATIC'  # Specify the asset you want to fetch data for
    fetch_present_data_and_save(asset_to_fetch)

    

    
#------------------------------------------------------------------------------------------------------------







def fetch_historical_data_and_save_Binance(asset):
    interval = '1m'  # 1 minute interval
    limit = 60  # Retrieve data for the past 60 minutes
    base_url = 'https://api.binance.com/api/v3/klines'
    trading_pair = exchange_market_lists['Binance'][asset]
    
    params = {
        'symbol': trading_pair,
        'interval': interval,
        'limit': limit
    }
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        historical_data = []

        for entry in data:
            timestamp = entry[0] / 1000  # Convert milliseconds to seconds
            if datetime.fromtimestamp(timestamp) > datetime.now() - timedelta(days=1):
                open_price = entry[1]
                high_price = entry[2]
                low_price = entry[3]
                close_price = entry[4]

                readable_timestamp = datetime.fromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
                historical_data.append({
                    'exchange': 'Binance',
                    'asset': asset,
                    'trading_pair': trading_pair,
                    'timestamp': readable_timestamp,
                    'open': open_price,
                    'high': high_price,
                    'low': low_price,
                    'close': close_price
                })

        try:
            # Load existing historical data from JSON file
            with open('his_market_data.json', 'r') as his_market_data_file:
                existing_data = json.load(his_market_data_file)
        except (FileNotFoundError, json.JSONDecodeError):
            existing_data = []

        # Append the new historical data to existing data
        existing_data.extend(historical_data)

        # Save the updated data to JSON file
        with open('his_market_data.json', 'w') as his_market_data_file:
            json.dump(existing_data, his_market_data_file, indent=4)
            print(f'Historical data for {asset} appended to his_market_data.json')
    else:
        print('Error occurred. Status Code:', response.status_code)

if __name__ == '__main__':
    asset_to_fetch = 'QUICK'  # Specify the asset you want to fetch data for
    fetch_historical_data_and_save(asset_to_fetch)

    
    
#---------------------------------------------------------------------------------------------------------------------
# Out:
# MATIC present data appended to market_data.json
# Historical data for QUICK appended to his_market_data.json

# %%
#view data in .json files

import json

def view_json_data(file_name):
    with open(file_name, 'r') as f:
        data = json.load(f)
        return data

if __name__ == '__main__':
    market_data = view_json_data('market_data.json')
    

    print('Market Data:')
    print(json.dumps(market_data, indent=4))
# Out:
# Market Data:
# [
#     {
#         "exchange": "Kraken",
#         "asset": "MATIC",
#         "trading_pair": "MATICUSD",
#         "price": "0.546400",
#         "volume": "215794.52278399",
#         "liquidity_score": null,
#         "fetch_time": "2023-08-26 14:04:36"
#     },
#     {
#         "exchange": "Coinbase",
#         "asset": "MATIC",
#         "trading_pair": "MATIC-USD",
#         "price": "0.5464",
#         "volume": "3230691.6",
#         "liquidity_score": null,
#         "fetch_time": "2023-08-26 14:07:04"
#     },
#     {
#         "exchange": "Binance",
#         "asset": "MATIC",
#         "trading_pair": "MATICUSDT",
#         "price": "0.54680000",
#         "volume": "16611385.73209000",
#         "liquidity_score": null,
#         "fetch_time": "2023-08-26 14:07:33"
#     }
# ]

# %%
#delete data in .json files


def clear_json_file(filename):
    with open(filename, 'w') as file:
        file.write('')

# Clear market_data.json
clear_json_file('market_data.json')
print('Data in market_data.json cleared.')

# Clear his_market_data.json
clear_json_file('his_market_data.json')
print('Data in his_market_data.json cleared.')
# Out:
# Data in market_data.json cleared.
# Data in his_market_data.json cleared.

# %%
import json

# Read data from the JSON file
file_path = 'his_market_data.json'  # Replace with the actual file path
with open(file_path, 'r') as json_file:
    data = json.load(json_file)

# Print the data
for entry in data:
    print('Exchange:', entry.get('exchange'))
    print('Asset:', entry.get('asset'))
    print('Trading Pair:', entry.get('trading_pair'))
    print('Timestamp:', entry.get('timestamp'))
    print('Open Price:', entry.get('open'))
    print('High Price:', entry.get('high'))
    print('Low Price:', entry.get('low'))
    print('Close Price:', entry.get('close'))
    print('---')
# Out:
# Exchange: Kraken
# Asset: MATIC
# Trading Pair: MATICUSD
# Timestamp: 2023-08-26 01:00:00
# Open Price: 0.5456
# High Price: 0.5485
# Low Price: 0.5438
# Close Price: 0.5457
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-26 01:00:00
# Open Price: 0.5464
# High Price: 0.5488
# Low Price: 0.5437
# Close Price: 0.5465
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-25 01:00:00
# Open Price: 0.5467
# High Price: 0.5559
# Low Price: 0.5352
# Close Price: 0.5461
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-24 01:00:00
# Open Price: 0.557
# High Price: 0.5602
# Low Price: 0.5369
# Close Price: 0.5471
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-23 01:00:00
# Open Price: 0.5489
# High Price: 0.5706
# Low Price: 0.5435
# Close Price: 0.557
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-22 01:00:00
# Open Price: 0.5568
# High Price: 0.5583
# Low Price: 0.528
# Close Price: 0.5488
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-21 01:00:00
# Open Price: 0.5801
# High Price: 0.5809
# Low Price: 0.5483
# Close Price: 0.557
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-20 01:00:00
# Open Price: 0.5771
# High Price: 0.5815
# Low Price: 0.5699
# Close Price: 0.5801
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-19 01:00:00
# Open Price: 0.5775
# High Price: 0.588
# Low Price: 0.5703
# Close Price: 0.5771
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-18 01:00:00
# Open Price: 0.5728
# High Price: 0.585
# Low Price: 0.5623
# Close Price: 0.5773
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-17 01:00:00
# Open Price: 0.623
# High Price: 0.6276
# Low Price: 0.5532
# Close Price: 0.5733
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-16 01:00:00
# Open Price: 0.638
# High Price: 0.6384
# Low Price: 0.6039
# Close Price: 0.623
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-15 01:00:00
# Open Price: 0.6789
# High Price: 0.6792
# Low Price: 0.6211
# Close Price: 0.6384
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-14 01:00:00
# Open Price: 0.6767
# High Price: 0.6848
# Low Price: 0.6712
# Close Price: 0.6789
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-13 01:00:00
# Open Price: 0.682
# High Price: 0.691
# Low Price: 0.6734
# Close Price: 0.6768
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-12 01:00:00
# Open Price: 0.6803
# High Price: 0.6835
# Low Price: 0.6766
# Close Price: 0.6821
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-11 01:00:00
# Open Price: 0.6847
# High Price: 0.6893
# Low Price: 0.6741
# Close Price: 0.6803
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-10 01:00:00
# Open Price: 0.6896
# High Price: 0.7015
# Low Price: 0.6829
# Close Price: 0.6846
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-09 01:00:00
# Open Price: 0.6859
# High Price: 0.6995
# Low Price: 0.68
# Close Price: 0.6896
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-08 01:00:00
# Open Price: 0.6657
# High Price: 0.6984
# Low Price: 0.6612
# Close Price: 0.6852
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-07 01:00:00
# Open Price: 0.6662
# High Price: 0.6829
# Low Price: 0.6475
# Close Price: 0.6655
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-06 01:00:00
# Open Price: 0.6673
# High Price: 0.6753
# Low Price: 0.6621
# Close Price: 0.6663
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-05 01:00:00
# Open Price: 0.6635
# High Price: 0.6683
# Low Price: 0.6565
# Close Price: 0.667
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-04 01:00:00
# Open Price: 0.667
# High Price: 0.678
# Low Price: 0.6564
# Close Price: 0.6633
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-03 01:00:00
# Open Price: 0.6793
# High Price: 0.6846
# Low Price: 0.6617
# Close Price: 0.6672
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-02 01:00:00
# Open Price: 0.7015
# High Price: 0.7031
# Low Price: 0.6745
# Close Price: 0.6796
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-08-01 01:00:00
# Open Price: 0.6872
# High Price: 0.7043
# Low Price: 0.6617
# Close Price: 0.7017
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-31 01:00:00
# Open Price: 0.6974
# High Price: 0.7078
# Low Price: 0.6803
# Close Price: 0.6875
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-30 01:00:00
# Open Price: 0.719
# High Price: 0.7196
# Low Price: 0.6809
# Close Price: 0.6974
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-29 01:00:00
# Open Price: 0.709
# High Price: 0.7246
# Low Price: 0.7075
# Close Price: 0.7186
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-28 01:00:00
# Open Price: 0.7168
# High Price: 0.7214
# Low Price: 0.7046
# Close Price: 0.709
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-27 01:00:00
# Open Price: 0.7228
# High Price: 0.7362
# Low Price: 0.7117
# Close Price: 0.7167
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-26 01:00:00
# Open Price: 0.7078
# High Price: 0.7314
# Low Price: 0.6966
# Close Price: 0.7224
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-25 01:00:00
# Open Price: 0.7276
# High Price: 0.7292
# Low Price: 0.702
# Close Price: 0.7079
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-24 01:00:00
# Open Price: 0.7575
# High Price: 0.7621
# Low Price: 0.7112
# Close Price: 0.7281
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-23 01:00:00
# Open Price: 0.7462
# High Price: 0.7681
# Low Price: 0.7392
# Close Price: 0.7572
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-22 01:00:00
# Open Price: 0.7694
# High Price: 0.7758
# Low Price: 0.74
# Close Price: 0.7461
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-21 01:00:00
# Open Price: 0.768
# High Price: 0.7821
# Low Price: 0.7582
# Close Price: 0.7694
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-20 01:00:00
# Open Price: 0.7436
# High Price: 0.802
# Low Price: 0.7422
# Close Price: 0.7681
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-19 01:00:00
# Open Price: 0.7385
# High Price: 0.7574
# Low Price: 0.728
# Close Price: 0.7436
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-18 01:00:00
# Open Price: 0.7774
# High Price: 0.7841
# Low Price: 0.7302
# Close Price: 0.7385
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-17 01:00:00
# Open Price: 0.7669
# High Price: 0.7897
# Low Price: 0.7508
# Close Price: 0.7776
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-16 01:00:00
# Open Price: 0.7998
# High Price: 0.803
# Low Price: 0.7641
# Close Price: 0.7671
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-15 01:00:00
# Open Price: 0.808
# High Price: 0.8262
# Low Price: 0.7948
# Close Price: 0.8
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-14 01:00:00
# Open Price: 0.851
# High Price: 0.8896
# Low Price: 0.7776
# Close Price: 0.8081
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-13 01:00:00
# Open Price: 0.7234
# High Price: 0.89
# Low Price: 0.7125
# Close Price: 0.8506
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-12 01:00:00
# Open Price: 0.7429
# High Price: 0.7589
# Low Price: 0.7146
# Close Price: 0.7234
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-11 01:00:00
# Open Price: 0.7354
# High Price: 0.7495
# Low Price: 0.7316
# Close Price: 0.7428
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-10 01:00:00
# Open Price: 0.6886
# High Price: 0.749
# Low Price: 0.6712
# Close Price: 0.735
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-09 01:00:00
# Open Price: 0.6795
# High Price: 0.7004
# Low Price: 0.678
# Close Price: 0.6885
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-08 01:00:00
# Open Price: 0.6768
# High Price: 0.6868
# Low Price: 0.6708
# Close Price: 0.6797
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-07 01:00:00
# Open Price: 0.6601
# High Price: 0.6805
# Low Price: 0.6531
# Close Price: 0.6767
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-06 01:00:00
# Open Price: 0.6702
# High Price: 0.7
# Low Price: 0.6476
# Close Price: 0.6601
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-05 01:00:00
# Open Price: 0.6958
# High Price: 0.7058
# Low Price: 0.66
# Close Price: 0.6703
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-04 01:00:00
# Open Price: 0.7147
# High Price: 0.7192
# Low Price: 0.6908
# Close Price: 0.6958
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-03 01:00:00
# Open Price: 0.6819
# High Price: 0.7211
# Low Price: 0.678
# Close Price: 0.7149
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-02 01:00:00
# Open Price: 0.6769
# High Price: 0.6888
# Low Price: 0.6608
# Close Price: 0.6819
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-07-01 01:00:00
# Open Price: 0.6613
# High Price: 0.6775
# Low Price: 0.6481
# Close Price: 0.677
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-30 01:00:00
# Open Price: 0.624
# High Price: 0.67
# Low Price: 0.6085
# Close Price: 0.6613
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-29 01:00:00
# Open Price: 0.6131
# High Price: 0.6441
# Low Price: 0.6109
# Close Price: 0.6241
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-28 01:00:00
# Open Price: 0.6622
# High Price: 0.6631
# Low Price: 0.6001
# Close Price: 0.6131
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-27 01:00:00
# Open Price: 0.6457
# High Price: 0.6728
# Low Price: 0.6428
# Close Price: 0.6622
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-26 01:00:00
# Open Price: 0.6667
# High Price: 0.6712
# Low Price: 0.637
# Close Price: 0.6458
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-25 01:00:00
# Open Price: 0.654
# High Price: 0.6803
# Low Price: 0.6486
# Close Price: 0.6665
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-24 01:00:00
# Open Price: 0.6765
# High Price: 0.6892
# Low Price: 0.6438
# Close Price: 0.6546
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-23 01:00:00
# Open Price: 0.6559
# High Price: 0.6959
# Low Price: 0.6553
# Close Price: 0.6762
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-22 01:00:00
# Open Price: 0.6681
# High Price: 0.7112
# Low Price: 0.6531
# Close Price: 0.6559
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-21 01:00:00
# Open Price: 0.6319
# High Price: 0.6773
# Low Price: 0.6283
# Close Price: 0.6684
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-20 01:00:00
# Open Price: 0.6146
# High Price: 0.6328
# Low Price: 0.5913
# Close Price: 0.6317
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-19 01:00:00
# Open Price: 0.5965
# High Price: 0.6216
# Low Price: 0.5901
# Close Price: 0.6149
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-18 01:00:00
# Open Price: 0.6133
# High Price: 0.6191
# Low Price: 0.5933
# Close Price: 0.5965
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-17 01:00:00
# Open Price: 0.5898
# High Price: 0.635
# Low Price: 0.5846
# Close Price: 0.6132
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-16 01:00:00
# Open Price: 0.5889
# High Price: 0.5993
# Low Price: 0.5575
# Close Price: 0.5898
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-15 01:00:00
# Open Price: 0.6184
# High Price: 0.627
# Low Price: 0.5586
# Close Price: 0.5895
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-14 01:00:00
# Open Price: 0.6447
# High Price: 0.6621
# Low Price: 0.6076
# Close Price: 0.6193
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-13 01:00:00
# Open Price: 0.6436
# High Price: 0.6786
# Low Price: 0.6237
# Close Price: 0.6449
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-12 01:00:00
# Open Price: 0.6352
# High Price: 0.6851
# Low Price: 0.6162
# Close Price: 0.6433
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-11 01:00:00
# Open Price: 0.6107
# High Price: 0.6605
# Low Price: 0.5912
# Close Price: 0.635
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-10 01:00:00
# Open Price: 0.7259
# High Price: 0.7262
# Low Price: 0.5059
# Close Price: 0.6102
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-09 01:00:00
# Open Price: 0.7812
# High Price: 0.789
# Low Price: 0.72
# Close Price: 0.7259
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-08 01:00:00
# Open Price: 0.7652
# High Price: 0.7853
# Low Price: 0.7553
# Close Price: 0.7812
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-07 01:00:00
# Open Price: 0.8225
# High Price: 0.8242
# Low Price: 0.7552
# Close Price: 0.7652
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-06 01:00:00
# Open Price: 0.8354
# High Price: 0.8371
# Low Price: 0.7874
# Close Price: 0.8226
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-05 01:00:00
# Open Price: 0.8918
# High Price: 0.8931
# Low Price: 0.825
# Close Price: 0.8358
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-04 01:00:00
# Open Price: 0.9001
# High Price: 0.9075
# Low Price: 0.8899
# Close Price: 0.8919
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-03 01:00:00
# Open Price: 0.8995
# High Price: 0.907
# Low Price: 0.8926
# Close Price: 0.9001
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-02 01:00:00
# Open Price: 0.8885
# High Price: 0.9091
# Low Price: 0.8816
# Close Price: 0.8995
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-06-01 01:00:00
# Open Price: 0.8921
# High Price: 0.8995
# Low Price: 0.8767
# Close Price: 0.8893
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-31 01:00:00
# Open Price: 0.9008
# High Price: 0.9058
# Low Price: 0.879
# Close Price: 0.8921
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-30 01:00:00
# Open Price: 0.909
# High Price: 0.9167
# Low Price: 0.8835
# Close Price: 0.9012
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-29 01:00:00
# Open Price: 0.9409
# High Price: 0.9507
# Low Price: 0.9039
# Close Price: 0.9089
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-28 01:00:00
# Open Price: 0.921
# High Price: 0.9555
# Low Price: 0.9181
# Close Price: 0.9409
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-27 01:00:00
# Open Price: 0.9107
# High Price: 0.9242
# Low Price: 0.907
# Close Price: 0.9209
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-26 01:00:00
# Open Price: 0.8893
# High Price: 0.9709
# Low Price: 0.8876
# Close Price: 0.9106
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-25 01:00:00
# Open Price: 0.8729
# High Price: 0.8999
# Low Price: 0.8542
# Close Price: 0.8896
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-24 01:00:00
# Open Price: 0.8896
# High Price: 0.8905
# Low Price: 0.8548
# Close Price: 0.8729
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-23 01:00:00
# Open Price: 0.8721
# High Price: 0.8935
# Low Price: 0.8694
# Close Price: 0.8896
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-22 01:00:00
# Open Price: 0.8569
# High Price: 0.8762
# Low Price: 0.8438
# Close Price: 0.8721
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-21 01:00:00
# Open Price: 0.8775
# High Price: 0.8801
# Low Price: 0.8532
# Close Price: 0.857
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-20 01:00:00
# Open Price: 0.8719
# High Price: 0.8798
# Low Price: 0.8644
# Close Price: 0.8771
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-19 01:00:00
# Open Price: 0.872
# High Price: 0.8809
# Low Price: 0.8629
# Close Price: 0.8719
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-18 01:00:00
# Open Price: 0.8871
# High Price: 0.8926
# Low Price: 0.8426
# Close Price: 0.8719
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-17 01:00:00
# Open Price: 0.8455
# High Price: 0.9016
# Low Price: 0.8402
# Close Price: 0.8869
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-16 01:00:00
# Open Price: 0.859
# High Price: 0.8653
# Low Price: 0.8349
# Close Price: 0.8455
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-15 01:00:00
# Open Price: 0.8594
# High Price: 0.878
# Low Price: 0.8467
# Close Price: 0.859
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-14 01:00:00
# Open Price: 0.8493
# High Price: 0.8692
# Low Price: 0.84
# Close Price: 0.8593
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-13 01:00:00
# Open Price: 0.8657
# High Price: 0.8666
# Low Price: 0.8478
# Close Price: 0.8492
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-12 01:00:00
# Open Price: 0.8411
# High Price: 0.8741
# Low Price: 0.8188
# Close Price: 0.8655
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-11 01:00:00
# Open Price: 0.8771
# High Price: 0.8778
# Low Price: 0.829
# Close Price: 0.8411
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-10 01:00:00
# Open Price: 0.8775
# High Price: 0.9052
# Low Price: 0.827
# Close Price: 0.8773
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-09 01:00:00
# Open Price: 0.9012
# High Price: 0.9084
# Low Price: 0.8667
# Close Price: 0.8775
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-08 01:00:00
# Open Price: 0.9631
# High Price: 0.9686
# Low Price: 0.8751
# Close Price: 0.9011
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-07 01:00:00
# Open Price: 0.9771
# High Price: 0.9867
# Low Price: 0.962
# Close Price: 0.9635
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-06 01:00:00
# Open Price: 0.9989
# High Price: 1.0062
# Low Price: 0.9512
# Close Price: 0.9769
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-05 01:00:00
# Open Price: 0.9827
# High Price: 1.0094
# Low Price: 0.9751
# Close Price: 0.9988
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-04 01:00:00
# Open Price: 1.006
# High Price: 1.0081
# Low Price: 0.9793
# Close Price: 0.983
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-03 01:00:00
# Open Price: 0.9774
# High Price: 1.0178
# Low Price: 0.963
# Close Price: 1.0061
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-02 01:00:00
# Open Price: 0.9592
# High Price: 0.9813
# Low Price: 0.9519
# Close Price: 0.9774
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-05-01 01:00:00
# Open Price: 0.981
# High Price: 0.9886
# Low Price: 0.9466
# Close Price: 0.9593
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-30 01:00:00
# Open Price: 1.0034
# High Price: 1.0162
# Low Price: 0.9751
# Close Price: 0.9807
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-29 01:00:00
# Open Price: 0.9995
# High Price: 1.0238
# Low Price: 0.9931
# Close Price: 1.0037
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-28 01:00:00
# Open Price: 1.0125
# High Price: 1.0162
# Low Price: 0.9797
# Close Price: 0.9991
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-27 01:00:00
# Open Price: 0.9865
# High Price: 1.031
# Low Price: 0.9793
# Close Price: 1.0127
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-26 01:00:00
# Open Price: 1.0044
# High Price: 1.059
# Low Price: 0.9439
# Close Price: 0.9864
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-25 01:00:00
# Open Price: 0.99
# High Price: 1.0171
# Low Price: 0.95
# Close Price: 1.0044
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-24 01:00:00
# Open Price: 1.0036
# High Price: 1.0239
# Low Price: 0.9728
# Close Price: 0.9897
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-23 01:00:00
# Open Price: 1.0247
# High Price: 1.0327
# Low Price: 0.979
# Close Price: 1.0039
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-22 01:00:00
# Open Price: 1.0112
# High Price: 1.0283
# Low Price: 1.0059
# Close Price: 1.0244
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-21 01:00:00
# Open Price: 1.0459
# High Price: 1.0571
# Low Price: 1
# Close Price: 1.0115
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-20 01:00:00
# Open Price: 1.0848
# High Price: 1.099
# Low Price: 1.0371
# Close Price: 1.046
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-19 01:00:00
# Open Price: 1.1723
# High Price: 1.178
# Low Price: 1.06
# Close Price: 1.0852
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-18 01:00:00
# Open Price: 1.1537
# High Price: 1.184
# Low Price: 1.1421
# Close Price: 1.1721
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-17 01:00:00
# Open Price: 1.1837
# High Price: 1.1857
# Low Price: 1.1504
# Close Price: 1.1534
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-16 01:00:00
# Open Price: 1.1714
# High Price: 1.1893
# Low Price: 1.1514
# Close Price: 1.1838
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-15 01:00:00
# Open Price: 1.1611
# High Price: 1.186
# Low Price: 1.1452
# Close Price: 1.1714
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-14 01:00:00
# Open Price: 1.1347
# High Price: 1.1914
# Low Price: 1.1345
# Close Price: 1.1607
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-13 01:00:00
# Open Price: 1.1048
# High Price: 1.1407
# Low Price: 1.0969
# Close Price: 1.1348
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-12 01:00:00
# Open Price: 1.113
# High Price: 1.1183
# Low Price: 1.0822
# Close Price: 1.1047
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-11 01:00:00
# Open Price: 1.1214
# High Price: 1.1323
# Low Price: 1.1094
# Close Price: 1.113
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-10 01:00:00
# Open Price: 1.1014
# High Price: 1.1251
# Low Price: 1.0885
# Close Price: 1.1217
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-09 01:00:00
# Open Price: 1.1027
# High Price: 1.1107
# Low Price: 1.0842
# Close Price: 1.1013
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-08 01:00:00
# Open Price: 1.1076
# High Price: 1.1183
# Low Price: 1.1003
# Close Price: 1.1026
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-07 01:00:00
# Open Price: 1.1154
# High Price: 1.1209
# Low Price: 1.0963
# Close Price: 1.1076
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-06 01:00:00
# Open Price: 1.1401
# High Price: 1.1419
# Low Price: 1.1076
# Close Price: 1.1157
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-05 01:00:00
# Open Price: 1.1391
# High Price: 1.1695
# Low Price: 1.1215
# Close Price: 1.1404
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-04 01:00:00
# Open Price: 1.097
# High Price: 1.1545
# Low Price: 1.0924
# Close Price: 1.1393
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-03 01:00:00
# Open Price: 1.0957
# High Price: 1.1195
# Low Price: 1.0694
# Close Price: 1.0971
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-02 01:00:00
# Open Price: 1.1129
# High Price: 1.1227
# Low Price: 1.0816
# Close Price: 1.0957
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-04-01 01:00:00
# Open Price: 1.1182
# High Price: 1.1289
# Low Price: 1.098
# Close Price: 1.1121
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-31 01:00:00
# Open Price: 1.0932
# High Price: 1.1239
# Low Price: 1.0732
# Close Price: 1.118
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-30 01:00:00
# Open Price: 1.1224
# High Price: 1.1428
# Low Price: 1.0792
# Close Price: 1.0933
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-29 01:00:00
# Open Price: 1.0869
# High Price: 1.1466
# Low Price: 1.0848
# Close Price: 1.1226
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-28 01:00:00
# Open Price: 1.0463
# High Price: 1.1101
# Low Price: 1.0333
# Close Price: 1.0867
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-27 01:00:00
# Open Price: 1.105
# High Price: 1.1095
# Low Price: 1.026
# Close Price: 1.046
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-26 01:00:00
# Open Price: 1.0795
# High Price: 1.1208
# Low Price: 1.0736
# Close Price: 1.1049
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-25 01:00:00
# Open Price: 1.0987
# High Price: 1.1145
# Low Price: 1.063
# Close Price: 1.0795
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-24 01:00:00
# Open Price: 1.1384
# High Price: 1.149
# Low Price: 1.0652
# Close Price: 1.0983
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-23 01:00:00
# Open Price: 1.1107
# High Price: 1.1601
# Low Price: 1.1022
# Close Price: 1.1385
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-22 01:00:00
# Open Price: 1.1564
# High Price: 1.1641
# Low Price: 1.0896
# Close Price: 1.1107
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-21 01:00:00
# Open Price: 1.1064
# High Price: 1.1711
# Low Price: 1.0831
# Close Price: 1.1564
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-20 01:00:00
# Open Price: 1.1694
# High Price: 1.1752
# Low Price: 1.1018
# Close Price: 1.1065
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-19 01:00:00
# Open Price: 1.173
# High Price: 1.2218
# Low Price: 1.1599
# Close Price: 1.1692
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-18 01:00:00
# Open Price: 1.2248
# High Price: 1.2535
# Low Price: 1.1674
# Close Price: 1.1734
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-17 01:00:00
# Open Price: 1.1498
# High Price: 1.2318
# Low Price: 1.1374
# Close Price: 1.2254
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-16 01:00:00
# Open Price: 1.116
# High Price: 1.1596
# Low Price: 1.101
# Close Price: 1.1504
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-15 01:00:00
# Open Price: 1.1999
# High Price: 1.2336
# Low Price: 1.0769
# Close Price: 1.116
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-14 01:00:00
# Open Price: 1.1981
# High Price: 1.249
# Low Price: 1.1482
# Close Price: 1.2008
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-13 01:00:00
# Open Price: 1.1581
# High Price: 1.2063
# Low Price: 1.0954
# Close Price: 1.1981
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-12 01:00:00
# Open Price: 1.0632
# High Price: 1.1596
# Low Price: 1.047
# Close Price: 1.1583
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-11 01:00:00
# Open Price: 1.0616
# High Price: 1.1008
# Low Price: 0.9925
# Close Price: 1.0635
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-10 01:00:00
# Open Price: 1.0164
# High Price: 1.07
# Low Price: 0.9424
# Close Price: 1.062
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-09 01:00:00
# Open Price: 1.0507
# High Price: 1.0939
# Low Price: 0.9731
# Close Price: 1.0174
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-08 01:00:00
# Open Price: 1.15
# High Price: 1.1574
# Low Price: 1.0381
# Close Price: 1.0509
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-07 01:00:00
# Open Price: 1.1315
# High Price: 1.169
# Low Price: 1.1119
# Close Price: 1.1501
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-06 01:00:00
# Open Price: 1.1359
# High Price: 1.1472
# Low Price: 1.1142
# Close Price: 1.1316
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-05 01:00:00
# Open Price: 1.1276
# High Price: 1.16
# Low Price: 1.1178
# Close Price: 1.136
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-04 01:00:00
# Open Price: 1.1691
# High Price: 1.1776
# Low Price: 1.101
# Close Price: 1.1276
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-03 01:00:00
# Open Price: 1.2275
# High Price: 1.2288
# Low Price: 1.1233
# Close Price: 1.1688
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-02 01:00:00
# Open Price: 1.2494
# High Price: 1.2541
# Low Price: 1.1915
# Close Price: 1.2276
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-03-01 01:00:00
# Open Price: 1.1967
# High Price: 1.2629
# Low Price: 1.1902
# Close Price: 1.2494
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-28 01:00:00
# Open Price: 1.2344
# High Price: 1.2442
# Low Price: 1.1808
# Close Price: 1.1968
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-27 01:00:00
# Open Price: 1.2819
# High Price: 1.288
# Low Price: 1.2137
# Close Price: 1.2342
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-26 01:00:00
# Open Price: 1.2461
# High Price: 1.3008
# Low Price: 1.2372
# Close Price: 1.2817
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-25 01:00:00
# Open Price: 1.2646
# High Price: 1.2784
# Low Price: 1.1954
# Close Price: 1.247
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-24 01:00:00
# Open Price: 1.3539
# High Price: 1.3636
# Low Price: 1.2435
# Close Price: 1.2646
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-23 01:00:00
# Open Price: 1.396
# High Price: 1.4189
# Low Price: 1.3332
# Close Price: 1.3538
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-22 01:00:00
# Open Price: 1.3866
# High Price: 1.4015
# Low Price: 1.32
# Close Price: 1.396
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-21 01:00:00
# Open Price: 1.4756
# High Price: 1.5029
# Low Price: 1.3621
# Close Price: 1.3867
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-20 01:00:00
# Open Price: 1.4786
# High Price: 1.5076
# Low Price: 1.4322
# Close Price: 1.4752
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-19 01:00:00
# Open Price: 1.4849
# High Price: 1.5366
# Low Price: 1.4618
# Close Price: 1.4781
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-18 01:00:00
# Open Price: 1.5242
# High Price: 1.5678
# Low Price: 1.4737
# Close Price: 1.4849
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-17 01:00:00
# Open Price: 1.3717
# High Price: 1.5496
# Low Price: 1.3697
# Close Price: 1.5243
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-16 01:00:00
# Open Price: 1.3288
# High Price: 1.4667
# Low Price: 1.3186
# Close Price: 1.3711
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-15 01:00:00
# Open Price: 1.2586
# High Price: 1.333
# Low Price: 1.2327
# Close Price: 1.3286
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-14 01:00:00
# Open Price: 1.1857
# High Price: 1.2607
# Low Price: 1.153
# Close Price: 1.2583
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-13 01:00:00
# Open Price: 1.2361
# High Price: 1.2443
# Low Price: 1.137
# Close Price: 1.1857
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-12 01:00:00
# Open Price: 1.2495
# High Price: 1.3031
# Low Price: 1.2225
# Close Price: 1.2361
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-11 01:00:00
# Open Price: 1.2299
# High Price: 1.2585
# Low Price: 1.213
# Close Price: 1.249
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-10 01:00:00
# Open Price: 1.2298
# High Price: 1.3136
# Low Price: 1.2093
# Close Price: 1.2299
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-09 01:00:00
# Open Price: 1.306
# High Price: 1.3483
# Low Price: 1.2022
# Close Price: 1.2295
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-08 01:00:00
# Open Price: 1.27
# High Price: 1.35
# Low Price: 1.2536
# Close Price: 1.306
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-07 01:00:00
# Open Price: 1.1909
# High Price: 1.272
# Low Price: 1.1878
# Close Price: 1.2701
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-06 01:00:00
# Open Price: 1.2033
# High Price: 1.2381
# Low Price: 1.1728
# Close Price: 1.1915
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-05 01:00:00
# Open Price: 1.2535
# High Price: 1.2598
# Low Price: 1.1841
# Close Price: 1.2034
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-04 01:00:00
# Open Price: 1.2455
# High Price: 1.2842
# Low Price: 1.2156
# Close Price: 1.2538
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-03 01:00:00
# Open Price: 1.1817
# High Price: 1.2535
# Low Price: 1.166
# Close Price: 1.2456
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-02 01:00:00
# Open Price: 1.1937
# High Price: 1.2573
# Low Price: 1.1744
# Close Price: 1.1813
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-02-01 01:00:00
# Open Price: 1.1093
# High Price: 1.2055
# Low Price: 1.0609
# Close Price: 1.1937
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-31 01:00:00
# Open Price: 1.0878
# High Price: 1.1234
# Low Price: 1.0774
# Close Price: 1.1095
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-30 01:00:00
# Open Price: 1.1783
# High Price: 1.1799
# Low Price: 1.0638
# Close Price: 1.0878
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-29 01:00:00
# Open Price: 1.1443
# High Price: 1.2
# Low Price: 1.1287
# Close Price: 1.178
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-28 01:00:00
# Open Price: 1.1588
# High Price: 1.1698
# Low Price: 1.0917
# Close Price: 1.1447
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-27 01:00:00
# Open Price: 1.1235
# High Price: 1.1899
# Low Price: 1.0603
# Close Price: 1.1593
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-26 01:00:00
# Open Price: 0.9924
# High Price: 1.1278
# Low Price: 0.9865
# Close Price: 1.1237
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-25 01:00:00
# Open Price: 0.9553
# High Price: 1.0188
# Low Price: 0.9323
# Close Price: 0.992
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-24 01:00:00
# Open Price: 0.9933
# High Price: 1.0421
# Low Price: 0.9424
# Close Price: 0.9556
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-23 01:00:00
# Open Price: 0.9943
# High Price: 1.0143
# Low Price: 0.9705
# Close Price: 0.9937
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-22 01:00:00
# Open Price: 0.99
# High Price: 1.032
# Low Price: 0.9747
# Close Price: 0.9943
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-21 01:00:00
# Open Price: 1.0265
# High Price: 1.0412
# Low Price: 0.9862
# Close Price: 0.9898
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-20 01:00:00
# Open Price: 0.9529
# High Price: 1.0282
# Low Price: 0.9372
# Close Price: 1.0261
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-19 01:00:00
# Open Price: 0.9375
# High Price: 0.9571
# Low Price: 0.9164
# Close Price: 0.953
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-18 01:00:00
# Open Price: 0.9939
# High Price: 1.0195
# Low Price: 0.9244
# Close Price: 0.9378
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-17 01:00:00
# Open Price: 1.0197
# High Price: 1.0382
# Low Price: 0.9921
# Close Price: 0.9938
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-16 01:00:00
# Open Price: 0.9831
# High Price: 1.0482
# Low Price: 0.9663
# Close Price: 1.02
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-15 01:00:00
# Open Price: 0.9983
# High Price: 1.0034
# Low Price: 0.9541
# Close Price: 0.9831
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-14 01:00:00
# Open Price: 0.9306
# High Price: 1.0553
# Low Price: 0.9291
# Close Price: 0.9988
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-13 01:00:00
# Open Price: 0.915
# High Price: 0.9417
# Low Price: 0.8955
# Close Price: 0.9304
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-12 01:00:00
# Open Price: 0.8914
# High Price: 0.9247
# Low Price: 0.8559
# Close Price: 0.9152
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-11 01:00:00
# Open Price: 0.8586
# High Price: 0.9009
# Low Price: 0.8445
# Close Price: 0.891
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-10 01:00:00
# Open Price: 0.8425
# High Price: 0.8612
# Low Price: 0.8317
# Close Price: 0.8586
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-09 01:00:00
# Open Price: 0.8405
# High Price: 0.8765
# Low Price: 0.8346
# Close Price: 0.8425
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-08 01:00:00
# Open Price: 0.8061
# High Price: 0.8447
# Low Price: 0.7963
# Close Price: 0.8405
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-07 01:00:00
# Open Price: 0.7991
# High Price: 0.8111
# Low Price: 0.7978
# Close Price: 0.8062
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-06 01:00:00
# Open Price: 0.7887
# High Price: 0.8003
# Low Price: 0.7704
# Close Price: 0.7991
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-05 01:00:00
# Open Price: 0.8066
# High Price: 0.8106
# Low Price: 0.7845
# Close Price: 0.7887
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-04 01:00:00
# Open Price: 0.7792
# High Price: 0.8144
# Low Price: 0.777
# Close Price: 0.8065
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-03 01:00:00
# Open Price: 0.7803
# High Price: 0.7885
# Low Price: 0.7702
# Close Price: 0.7793
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-02 01:00:00
# Open Price: 0.7599
# High Price: 0.7903
# Low Price: 0.7487
# Close Price: 0.7805
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2023-01-01 01:00:00
# Open Price: 0.7578
# High Price: 0.7624
# Low Price: 0.7472
# Close Price: 0.76
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-31 01:00:00
# Open Price: 0.7612
# High Price: 0.7718
# Low Price: 0.7532
# Close Price: 0.7577
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-30 01:00:00
# Open Price: 0.7764
# High Price: 0.781
# Low Price: 0.7473
# Close Price: 0.761
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-29 01:00:00
# Open Price: 0.7825
# High Price: 0.7863
# Low Price: 0.7685
# Close Price: 0.7766
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-28 01:00:00
# Open Price: 0.8062
# High Price: 0.8082
# Low Price: 0.7743
# Close Price: 0.7823
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-27 01:00:00
# Open Price: 0.8152
# High Price: 0.8193
# Low Price: 0.7971
# Close Price: 0.806
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-26 01:00:00
# Open Price: 0.7949
# High Price: 0.8167
# Low Price: 0.7935
# Close Price: 0.8152
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-25 01:00:00
# Open Price: 0.7957
# High Price: 0.799
# Low Price: 0.7856
# Close Price: 0.7949
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-24 01:00:00
# Open Price: 0.7991
# High Price: 0.8011
# Low Price: 0.7928
# Close Price: 0.7956
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-23 01:00:00
# Open Price: 0.7964
# High Price: 0.8073
# Low Price: 0.7913
# Close Price: 0.7991
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-22 01:00:00
# Open Price: 0.7938
# High Price: 0.7975
# Low Price: 0.7697
# Close Price: 0.7963
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-21 01:00:00
# Open Price: 0.8015
# High Price: 0.8035
# Low Price: 0.7855
# Close Price: 0.7938
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-20 01:00:00
# Open Price: 0.7737
# High Price: 0.809
# Low Price: 0.7678
# Close Price: 0.8013
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-19 01:00:00
# Open Price: 0.8137
# High Price: 0.8218
# Low Price: 0.7576
# Close Price: 0.7738
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-18 01:00:00
# Open Price: 0.8164
# High Price: 0.8263
# Low Price: 0.8019
# Close Price: 0.8138
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-17 01:00:00
# Open Price: 0.7956
# High Price: 0.8189
# Low Price: 0.7817
# Close Price: 0.816
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-16 01:00:00
# Open Price: 0.8784
# High Price: 0.891
# Low Price: 0.7817
# Close Price: 0.7956
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-15 01:00:00
# Open Price: 0.9031
# High Price: 0.9064
# Low Price: 0.8717
# Close Price: 0.8786
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-14 01:00:00
# Open Price: 0.9238
# High Price: 0.9383
# Low Price: 0.8932
# Close Price: 0.903
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-13 01:00:00
# Open Price: 0.9112
# High Price: 0.9424
# Low Price: 0.8795
# Close Price: 0.924
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-12 01:00:00
# Open Price: 0.892
# High Price: 0.913
# Low Price: 0.8696
# Close Price: 0.9111
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-11 01:00:00
# Open Price: 0.9085
# High Price: 0.9151
# Low Price: 0.8885
# Close Price: 0.8921
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-10 01:00:00
# Open Price: 0.9095
# High Price: 0.9165
# Low Price: 0.9006
# Close Price: 0.9084
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-09 01:00:00
# Open Price: 0.9278
# High Price: 0.9346
# Low Price: 0.908
# Close Price: 0.9097
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-08 01:00:00
# Open Price: 0.8979
# High Price: 0.9301
# Low Price: 0.8874
# Close Price: 0.9278
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-07 01:00:00
# Open Price: 0.9177
# High Price: 0.9198
# Low Price: 0.8707
# Close Price: 0.8978
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-06 01:00:00
# Open Price: 0.9117
# High Price: 0.9214
# Low Price: 0.8965
# Close Price: 0.9176
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-05 01:00:00
# Open Price: 0.9213
# High Price: 0.9452
# Low Price: 0.8999
# Close Price: 0.9115
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-04 01:00:00
# Open Price: 0.9029
# High Price: 0.9237
# Low Price: 0.9013
# Close Price: 0.9214
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-03 01:00:00
# Open Price: 0.9489
# High Price: 0.95
# Low Price: 0.8997
# Close Price: 0.9027
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-02 01:00:00
# Open Price: 0.9087
# High Price: 0.9493
# Low Price: 0.8984
# Close Price: 0.9489
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-12-01 01:00:00
# Open Price: 0.9331
# High Price: 0.9454
# Low Price: 0.9057
# Close Price: 0.9087
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-30 01:00:00
# Open Price: 0.8383
# High Price: 0.9446
# Low Price: 0.8369
# Close Price: 0.933
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-29 01:00:00
# Open Price: 0.8213
# High Price: 0.8497
# Low Price: 0.8129
# Close Price: 0.8382
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-28 01:00:00
# Open Price: 0.8433
# High Price: 0.8486
# Low Price: 0.8036
# Close Price: 0.8209
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-27 01:00:00
# Open Price: 0.846
# High Price: 0.8655
# Low Price: 0.8402
# Close Price: 0.8435
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-26 01:00:00
# Open Price: 0.8439
# High Price: 0.8712
# Low Price: 0.8382
# Close Price: 0.8459
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-25 01:00:00
# Open Price: 0.8483
# High Price: 0.8491
# Low Price: 0.8188
# Close Price: 0.8436
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-24 01:00:00
# Open Price: 0.8607
# High Price: 0.8905
# Low Price: 0.8412
# Close Price: 0.8482
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-23 01:00:00
# Open Price: 0.8504
# High Price: 0.8721
# Low Price: 0.8354
# Close Price: 0.8607
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-22 01:00:00
# Open Price: 0.7953
# High Price: 0.8659
# Low Price: 0.7775
# Close Price: 0.8502
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-21 01:00:00
# Open Price: 0.8058
# High Price: 0.8204
# Low Price: 0.7633
# Close Price: 0.7953
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-20 01:00:00
# Open Price: 0.8752
# High Price: 0.8806
# Low Price: 0.7983
# Close Price: 0.8058
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-19 01:00:00
# Open Price: 0.8783
# High Price: 0.8826
# Low Price: 0.8487
# Close Price: 0.8753
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-18 01:00:00
# Open Price: 0.873
# High Price: 0.8993
# Low Price: 0.8669
# Close Price: 0.8783
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-17 01:00:00
# Open Price: 0.8974
# High Price: 0.9115
# Low Price: 0.861
# Close Price: 0.8732
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-16 01:00:00
# Open Price: 0.9409
# High Price: 0.9551
# Low Price: 0.878
# Close Price: 0.897
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-15 01:00:00
# Open Price: 0.917
# High Price: 0.9726
# Low Price: 0.9058
# Close Price: 0.9409
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-14 01:00:00
# Open Price: 0.8886
# High Price: 0.9641
# Low Price: 0.8308
# Close Price: 0.9164
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-13 01:00:00
# Open Price: 0.938
# High Price: 0.9668
# Low Price: 0.8641
# Close Price: 0.8883
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-12 01:00:00
# Open Price: 1.0626
# High Price: 1.0653
# Low Price: 0.924
# Close Price: 0.9379
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-11 01:00:00
# Open Price: 1.1209
# High Price: 1.1565
# Low Price: 0.9671
# Close Price: 1.0624
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-10 01:00:00
# Open Price: 0.8152
# High Price: 1.1574
# Low Price: 0.8004
# Close Price: 1.1213
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-09 01:00:00
# Open Price: 1.0442
# High Price: 1.0717
# Low Price: 0.761
# Close Price: 0.8152
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-08 01:00:00
# Open Price: 1.2573
# High Price: 1.275
# Low Price: 0.9
# Close Price: 1.0447
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-07 01:00:00
# Open Price: 1.1345
# High Price: 1.2918
# Low Price: 1.1288
# Close Price: 1.2572
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-06 01:00:00
# Open Price: 1.185
# High Price: 1.2152
# Low Price: 1.1311
# Close Price: 1.135
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-05 01:00:00
# Open Price: 1.1694
# High Price: 1.3042
# Low Price: 1.1526
# Close Price: 1.1847
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-04 01:00:00
# Open Price: 0.9509
# High Price: 1.1984
# Low Price: 0.9503
# Close Price: 1.1692
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-03 01:00:00
# Open Price: 0.8736
# High Price: 0.9912
# Low Price: 0.8684
# Close Price: 0.9511
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-02 01:00:00
# Open Price: 0.874
# High Price: 0.897
# Low Price: 0.8364
# Close Price: 0.8735
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-11-01 01:00:00
# Open Price: 0.9028
# High Price: 0.9096
# Low Price: 0.873
# Close Price: 0.874
# ---
# Exchange: Coinbase
# Asset: MATIC
# Trading Pair: MATIC-USD
# Timestamp: 2022-10-31 01:00:00
# Open Price: 0.9087
# High Price: 0.93
# Low Price: 0.893
# Close Price: 0.9029
# ---

# %%
# Assuming the structure of each entry is:
# [exchange, asset, trading_pair, timestamp, open_price, high_price, low_price, close_price]

# Load historical data from JSON file
with open('his_market_data.json', 'r') as his_market_data_file:
    historical_data = json.load(his_market_data_file)

# Print the data
for entry in historical_data:
    exchange = entry[0]
    asset = entry[1]
    trading_pair = entry[2]
    timestamp = entry[3]
    open_price = entry[4]
    high_price = entry[5]
    low_price = entry[6]
    close_price = entry[7]
    
    print('Exchange:', exchange)
    print('Asset:', asset)
    print('Trading Pair:', trading_pair)
    print('Timestamp:', timestamp)
    print('Open Price:', open_price)
    print('High Price:', high_price)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 16
#      14 open_price = entry[4]
#      15 high_price = entry[5]
# ---> 16 low_price = entry[6]
#      17 close_price = entry[7]
#      19 print('Exchange:', exchange)
#
# IndexError: list index out of range

# %%
def fetch_present_data_and_save(asset):
    base_url = 'https://api.binance.com/api/v3/ticker/24hr'
    trading_pair = exchange_market_lists['Binance'][asset]
    params = {'symbol': trading_pair}
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        present_data = {
            'exchange': 'Binance',
            'asset': asset,
            'trading_pair': trading_pair,
            'price': data['lastPrice'],
            'volume': data['quoteVolume'],
            'liquidity_score': None,
            'fetch_time': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }

        try:
            # Load existing data from JSON file
            with open('market_data.json', 'r') as market_data_file:
                existing_data = json.load(market_data_file)
        except (FileNotFoundError, json.JSONDecodeError):
            existing_data = []

        # Append the new present data to existing data
        existing_data.append(present_data)

        # Save the updated data to JSON file
        with open('market_data.json', 'w') as market_data_file:
            json.dump(existing_data, market_data_file, indent=4)
            print(f'{asset} present data appended to market_data.json')
    else:
        print('Error occurred. Status Code:', response.status_code)

if __name__ == '__main__':
    asset_to_fetch = 'MATIC'  # Specify the asset you want to fetch data for
    fetch_present_data_and_save(asset_to_fetch)
# Out:
# MATIC present data appended to market_data.json
