# %%
import requests
from datetime import datetime

def fetch_present_data_kucoin(asset):
    base_url = 'https://api.kucoin.com/api/v1/market/stats'
    trading_pair = f'{asset}-USDT'
    params = {'symbol': trading_pair}
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()['data']
        present_data = {
            'exchange': 'KuCoin',
            'asset': asset,
            'trading_pair': trading_pair,
            'price': data['last'],
            'volume': data['vol'],
            'liquidity_score': None,
            'fetch_time': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }
        return present_data
    else:
        print('Error occurred. Status Code:', response.status_code)
        return None

if __name__ == '__main__':
    asset_to_fetch = 'MATIC'  # Specify the asset you want to fetch data for
    present_data = fetch_present_data_kucoin(asset_to_fetch)
    
    if present_data:
        print(f'Present data for {asset_to_fetch} from KuCoin:')
        print(f"Exchange: {present_data['exchange']}")
        print(f"Asset: {present_data['asset']}")
        print(f"Trading Pair: {present_data['trading_pair']}")
        print(f"Price: {present_data['price']}")
        print(f"Volume: {present_data['volume']}")
        print(f"Fetch Time: {present_data['fetch_time']}")
    else:
        print(f'Failed to fetch present data for {asset_to_fetch} from KuCoin.')
# Out:
# Present data for MATIC from KuCoin:
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Price: 0.5747
# Volume: 10295744.27047765
# Fetch Time: 2023-08-30 14:44:32

# %%
import requests
from datetime import datetime

def fetch_kucoin_historical_data(asset):
    interval = '1min'  # 1 day interval
    limit = 30  # Retrieve data for the past 30 days
    base_url = 'https://api.kucoin.com/api/v1/market/candles'
    trading_pair = f'{asset}-USDT'
    
    params = {
        'symbol': trading_pair,
        'type': interval,
        'limit': limit
    }
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()['data']
        
        for entry in data:
            timestamp = int(entry[0]) / 1000  # Convert milliseconds to seconds
            readable_timestamp = datetime.fromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
            open_price = entry[1]
            high_price = entry[2]
            low_price = entry[3]
            close_price = entry[4]

            print(f'Exchange: KuCoin')
            print(f'Asset: {asset}')
            print(f'Trading Pair: {trading_pair}')
            print(f'Timestamp: {readable_timestamp}')
            print(f'Open Price: {open_price}')
            print(f'High Price: {high_price}')
            print(f'Low Price: {low_price}')
            print(f'Close Price: {close_price}')
            print('--------------------')
    else:
        print('Error occurred. Status Code:', response.status_code)

if __name__ == '__main__':
    asset_to_fetch = 'MATIC'  # Specify the asset you want to fetch data for
    fetch_kucoin_historical_data(asset_to_fetch)
# Out:
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:23
# Open Price: 0.575
# High Price: 0.575
# Low Price: 0.575
# Close Price: 0.575
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:23
# Open Price: 0.5743
# High Price: 0.5745
# Low Price: 0.5745
# Close Price: 0.5741
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:23
# Open Price: 0.5747
# High Price: 0.5747
# Low Price: 0.5747
# Close Price: 0.5747
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:23
# Open Price: 0.5745
# High Price: 0.5745
# Low Price: 0.5745
# Close Price: 0.5745
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:23
# Open Price: 0.5747
# High Price: 0.5742
# Low Price: 0.5747
# Close Price: 0.5742
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:23
# Open Price: 0.5749
# High Price: 0.5749
# Low Price: 0.5749
# Close Price: 0.5746
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:23
# Open Price: 0.5744
# High Price: 0.5752
# Low Price: 0.5752
# Close Price: 0.5744
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:23
# Open Price: 0.5747
# High Price: 0.5747
# Low Price: 0.5747
# Close Price: 0.5747
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5749
# High Price: 0.5748
# Low Price: 0.5749
# Close Price: 0.5748
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5737
# High Price: 0.575
# Low Price: 0.575
# Close Price: 0.5736
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5742
# High Price: 0.5741
# Low Price: 0.5742
# Close Price: 0.5736
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5754
# High Price: 0.5742
# Low Price: 0.5754
# Close Price: 0.5742
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5737
# High Price: 0.5758
# Low Price: 0.5758
# Close Price: 0.5737
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5736
# High Price: 0.5735
# Low Price: 0.5736
# Close Price: 0.5715
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.575
# High Price: 0.5742
# Low Price: 0.5752
# Close Price: 0.5736
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5764
# High Price: 0.5752
# Low Price: 0.5764
# Close Price: 0.5747
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5765
# High Price: 0.5764
# Low Price: 0.5765
# Close Price: 0.5764
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5765
# High Price: 0.5765
# Low Price: 0.5765
# Close Price: 0.5765
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.577
# High Price: 0.5767
# Low Price: 0.5771
# Close Price: 0.5766
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.577
# High Price: 0.5768
# Low Price: 0.577
# Close Price: 0.5767
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5769
# High Price: 0.5769
# Low Price: 0.5769
# Close Price: 0.5769
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5777
# High Price: 0.5775
# Low Price: 0.5777
# Close Price: 0.5775
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5776
# High Price: 0.5777
# Low Price: 0.5777
# Close Price: 0.5776
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5776
# High Price: 0.5776
# Low Price: 0.5776
# Close Price: 0.5774
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:22
# Open Price: 0.5781
# High Price: 0.5775
# Low Price: 0.5781
# Close Price: 0.5775
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5778
# High Price: 0.5781
# Low Price: 0.5781
# Close Price: 0.5778
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5779
# High Price: 0.5779
# Low Price: 0.5779
# Close Price: 0.5779
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5779
# High Price: 0.5778
# Low Price: 0.5779
# Close Price: 0.5778
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5782
# High Price: 0.5782
# Low Price: 0.5782
# Close Price: 0.5782
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5783
# High Price: 0.5782
# Low Price: 0.5784
# Close Price: 0.5781
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5776
# High Price: 0.5784
# Low Price: 0.5785
# Close Price: 0.5776
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5782
# High Price: 0.5777
# Low Price: 0.5782
# Close Price: 0.5776
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5781
# High Price: 0.5782
# Low Price: 0.5782
# Close Price: 0.578
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5781
# High Price: 0.5781
# Low Price: 0.5781
# Close Price: 0.5781
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5779
# High Price: 0.5779
# Low Price: 0.578
# Close Price: 0.5779
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5774
# High Price: 0.5777
# Low Price: 0.5777
# Close Price: 0.5773
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5773
# High Price: 0.5774
# Low Price: 0.5774
# Close Price: 0.5772
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5773
# High Price: 0.5773
# Low Price: 0.5773
# Close Price: 0.5772
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5773
# High Price: 0.5774
# Low Price: 0.5775
# Close Price: 0.5773
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5765
# High Price: 0.5773
# Low Price: 0.5778
# Close Price: 0.5762
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.576
# High Price: 0.5764
# Low Price: 0.5764
# Close Price: 0.5759
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:21
# Open Price: 0.5755
# High Price: 0.5757
# Low Price: 0.5757
# Close Price: 0.5754
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5758
# High Price: 0.5756
# Low Price: 0.5758
# Close Price: 0.5756
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5755
# High Price: 0.5756
# Low Price: 0.5756
# Close Price: 0.5755
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5753
# High Price: 0.5753
# Low Price: 0.5754
# Close Price: 0.5753
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5752
# High Price: 0.5752
# Low Price: 0.5752
# Close Price: 0.5752
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5753
# High Price: 0.5752
# Low Price: 0.5753
# Close Price: 0.5752
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5756
# High Price: 0.5757
# Low Price: 0.5757
# Close Price: 0.5756
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5756
# High Price: 0.5757
# Low Price: 0.5758
# Close Price: 0.5756
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5753
# High Price: 0.5756
# Low Price: 0.5756
# Close Price: 0.5753
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5748
# High Price: 0.5749
# Low Price: 0.5749
# Close Price: 0.5744
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5746
# High Price: 0.5748
# Low Price: 0.5748
# Close Price: 0.5746
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5751
# High Price: 0.5751
# Low Price: 0.5751
# Close Price: 0.5751
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5751
# High Price: 0.5751
# Low Price: 0.5751
# Close Price: 0.5751
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5748
# High Price: 0.5751
# Low Price: 0.5751
# Close Price: 0.5748
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5745
# High Price: 0.5749
# Low Price: 0.5749
# Close Price: 0.5745
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5745
# High Price: 0.5745
# Low Price: 0.5745
# Close Price: 0.5745
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:20
# Open Price: 0.5745
# High Price: 0.5745
# Low Price: 0.5745
# Close Price: 0.5745
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5745
# High Price: 0.5746
# Low Price: 0.5747
# Close Price: 0.5745
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5753
# High Price: 0.5747
# Low Price: 0.5753
# Close Price: 0.5747
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5752
# High Price: 0.5753
# Low Price: 0.5753
# Close Price: 0.5752
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5758
# High Price: 0.5755
# Low Price: 0.5758
# Close Price: 0.5755
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5755
# High Price: 0.5757
# Low Price: 0.5758
# Close Price: 0.5753
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5751
# High Price: 0.5755
# Low Price: 0.5755
# Close Price: 0.5748
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5746
# High Price: 0.5754
# Low Price: 0.5754
# Close Price: 0.5745
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5745
# High Price: 0.5746
# Low Price: 0.5747
# Close Price: 0.5737
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5735
# High Price: 0.5746
# Low Price: 0.5746
# Close Price: 0.5735
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5735
# High Price: 0.5736
# Low Price: 0.5736
# Close Price: 0.5732
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5743
# High Price: 0.5734
# Low Price: 0.5743
# Close Price: 0.5734
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5746
# High Price: 0.5744
# Low Price: 0.5747
# Close Price: 0.5742
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5744
# High Price: 0.5747
# Low Price: 0.575
# Close Price: 0.5744
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5748
# High Price: 0.5744
# Low Price: 0.5748
# Close Price: 0.5744
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5751
# High Price: 0.5749
# Low Price: 0.5752
# Close Price: 0.5749
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5756
# High Price: 0.5752
# Low Price: 0.5756
# Close Price: 0.5752
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:19
# Open Price: 0.5756
# High Price: 0.5755
# Low Price: 0.5756
# Close Price: 0.5752
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5759
# High Price: 0.5757
# Low Price: 0.5759
# Close Price: 0.5757
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5761
# High Price: 0.5761
# Low Price: 0.5761
# Close Price: 0.5761
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5766
# High Price: 0.5764
# Low Price: 0.5766
# Close Price: 0.5764
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5765
# High Price: 0.5764
# Low Price: 0.5765
# Close Price: 0.5764
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5767
# High Price: 0.5768
# Low Price: 0.5768
# Close Price: 0.5767
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5775
# High Price: 0.5769
# Low Price: 0.5775
# Close Price: 0.5769
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5771
# High Price: 0.5771
# Low Price: 0.5771
# Close Price: 0.5771
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.577
# High Price: 0.5773
# Low Price: 0.5773
# Close Price: 0.577
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5766
# High Price: 0.5766
# Low Price: 0.5766
# Close Price: 0.5766
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5773
# High Price: 0.5767
# Low Price: 0.5774
# Close Price: 0.5767
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5773
# High Price: 0.5773
# Low Price: 0.5774
# Close Price: 0.5772
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5774
# High Price: 0.5774
# Low Price: 0.5775
# Close Price: 0.5771
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5775
# High Price: 0.5775
# Low Price: 0.5775
# Close Price: 0.5774
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5773
# High Price: 0.5773
# Low Price: 0.5774
# Close Price: 0.5773
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.577
# High Price: 0.5772
# Low Price: 0.5772
# Close Price: 0.577
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5774
# High Price: 0.5774
# Low Price: 0.5774
# Close Price: 0.5774
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:18
# Open Price: 0.5771
# High Price: 0.5774
# Low Price: 0.5774
# Close Price: 0.5771
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:17
# Open Price: 0.5775
# High Price: 0.5773
# Low Price: 0.5775
# Close Price: 0.5773
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:17
# Open Price: 0.5772
# High Price: 0.5775
# Low Price: 0.5776
# Close Price: 0.5772
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:17
# Open Price: 0.5774
# High Price: 0.5773
# Low Price: 0.5774
# Close Price: 0.5773
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:17
# Open Price: 0.5772
# High Price: 0.5773
# Low Price: 0.5773
# Close Price: 0.5772
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:17
# Open Price: 0.5769
# High Price: 0.577
# Low Price: 0.577
# Close Price: 0.5769
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:17
# Open Price: 0.5764
# High Price: 0.5764
# Low Price: 0.5764
# Close Price: 0.5764
# --------------------
# Exchange: KuCoin
# Asset: MATIC
# Trading Pair: MATIC-USDT
# Timestamp: 1970-01-20 15:23:17
# Open Price: 0.5766
# High Price: 0.5764
# Low Price: 0.5766
# Close Price: 0.5764
# --------------------
