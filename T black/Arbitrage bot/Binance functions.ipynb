# %%
import requests
import json
from datetime import datetime, timedelta
from exchange_markets import exchange_market_lists

def fetch_present_data_and_save(asset):
    base_url = 'https://api.binance.com/api/v3/ticker/24hr'
    trading_pair = exchange_market_lists['Binance'][asset]
    params = {'symbol': trading_pair}
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        present_data = {
            'exchange': 'Binance',
            'asset': asset,
            'trading_pair': trading_pair,
            'price': data['lastPrice'],
            'volume': data['quoteVolume'],
            'liquidity_score': None,
            'fetch_time': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }

        try:
            # Load existing data from JSON file
            with open('market_data.json', 'r') as market_data_file:
                existing_data = json.load(market_data_file)
        except (FileNotFoundError, json.JSONDecodeError):
            existing_data = []

        # Append the new present data to existing data
        existing_data.append(present_data)

        # Save the updated data to JSON file
        with open('market_data.json', 'w') as market_data_file:
            json.dump(existing_data, market_data_file, indent=4)
            print(f'{asset} present data appended to market_data.json')
    else:
        print('Error occurred. Status Code:', response.status_code)

if __name__ == '__main__':
    asset_to_fetch = 'MATIC'  # Specify the asset you want to fetch data for
    fetch_present_data_and_save(asset_to_fetch)

    

    
#------------------------------------------------------------------------------------------------------------







def fetch_historical_data_and_save(asset):
    interval = '1m'  # 1 minute interval
    limit = 60  # Retrieve data for the past 60 minutes
    base_url = 'https://api.binance.com/api/v3/klines'
    trading_pair = exchange_market_lists['Binance'][asset]
    
    params = {
        'symbol': trading_pair,
        'interval': interval,
        'limit': limit
    }
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        historical_data = []

        for entry in data:
            timestamp = entry[0] / 1000  # Convert milliseconds to seconds
            if datetime.fromtimestamp(timestamp) > datetime.now() - timedelta(days=1):
                open_price = entry[1]
                high_price = entry[2]
                low_price = entry[3]
                close_price = entry[4]

                readable_timestamp = datetime.fromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
                historical_data.append({
                    'exchange': 'Binance',
                    'asset': asset,
                    'trading_pair': trading_pair,
                    'timestamp': readable_timestamp,
                    'open': open_price,
                    'high': high_price,
                    'low': low_price,
                    'close': close_price
                })

        try:
            # Load existing historical data from JSON file
            with open('his_market_data.json', 'r') as his_market_data_file:
                existing_data = json.load(his_market_data_file)
        except (FileNotFoundError, json.JSONDecodeError):
            existing_data = []

        # Append the new historical data to existing data
        existing_data.extend(historical_data)

        # Save the updated data to JSON file
        with open('his_market_data.json', 'w') as his_market_data_file:
            json.dump(existing_data, his_market_data_file, indent=4)
            print(f'Historical data for {asset} appended to his_market_data.json')
    else:
        print('Error occurred. Status Code:', response.status_code)

if __name__ == '__main__':
    asset_to_fetch = 'QUICK'  # Specify the asset you want to fetch data for
    fetch_historical_data_and_save(asset_to_fetch)

    
    
#---------------------------------------------------------------------------------------------------------------------
# Out:
# MATIC present data appended to market_data.json
# Historical data for QUICK appended to his_market_data.json

# %%
#view data in .json files

import json

def view_json_data(file_name):
    with open(file_name, 'r') as f:
        data = json.load(f)
        return data

if __name__ == '__main__':
    market_data = view_json_data('market_data.json')
    

    print('Market Data:')
    print(json.dumps(market_data, indent=4))
# Out:
# Market Data:
# [
#     {
#         "exchange": "Kraken",
#         "asset": "MATIC",
#         "trading_pair": "MATICEUR",
#         "price": "0.500400",
#         "volume": "209788.11374127",
#         "liquidity_score": null,
#         "fetch_time": "2023-08-24 17:13:03"
#     }
# ]

# %%
#delete data in .json files


def clear_json_file(filename):
    with open(filename, 'w') as file:
        file.write('')

# Clear market_data.json
clear_json_file('market_data.json')
print('Data in market_data.json cleared.')

# Clear his_market_data.json
clear_json_file('his_market_data.json')
print('Data in his_market_data.json cleared.')
# Out:
# Data in market_data.json cleared.
# Data in his_market_data.json cleared.

# %%
import json

# Read data from the JSON file
file_path = 'his_market_data.json'  # Replace with the actual file path
with open(file_path, 'r') as json_file:
    data = json.load(json_file)

# Print the data
for entry in data:
    print('Exchange:', entry['exchange'])
    print('Asset:', entry['asset'])
    print('Trading Pair:', entry['trading_pair'])
    print('Timestamp:', entry['timestamp'])
    print('Open Price:', entry['open'])
    print('High Price:', entry['high'])
    print('Low Price:', entry['low'])
    print('Close Price:', entry['close'])
    print('---')
# Out:
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:01:00
# Open Price: 0.54960000
# High Price: 0.54960000
# Low Price: 0.54940000
# Close Price: 0.54960000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:02:00
# Open Price: 0.54960000
# High Price: 0.54970000
# Low Price: 0.54950000
# Close Price: 0.54950000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:03:00
# Open Price: 0.54950000
# High Price: 0.54980000
# Low Price: 0.54920000
# Close Price: 0.54920000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:04:00
# Open Price: 0.54920000
# High Price: 0.54970000
# Low Price: 0.54910000
# Close Price: 0.54970000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:05:00
# Open Price: 0.54960000
# High Price: 0.55040000
# Low Price: 0.54960000
# Close Price: 0.55040000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:06:00
# Open Price: 0.55060000
# High Price: 0.55070000
# Low Price: 0.54970000
# Close Price: 0.54970000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:07:00
# Open Price: 0.54970000
# High Price: 0.54980000
# Low Price: 0.54890000
# Close Price: 0.54900000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:08:00
# Open Price: 0.54910000
# High Price: 0.54910000
# Low Price: 0.54870000
# Close Price: 0.54870000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:09:00
# Open Price: 0.54880000
# High Price: 0.54930000
# Low Price: 0.54850000
# Close Price: 0.54920000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:10:00
# Open Price: 0.54910000
# High Price: 0.54910000
# Low Price: 0.54820000
# Close Price: 0.54820000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:11:00
# Open Price: 0.54830000
# High Price: 0.54910000
# Low Price: 0.54800000
# Close Price: 0.54910000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:12:00
# Open Price: 0.54910000
# High Price: 0.54920000
# Low Price: 0.54880000
# Close Price: 0.54880000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:13:00
# Open Price: 0.54880000
# High Price: 0.54890000
# Low Price: 0.54860000
# Close Price: 0.54880000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:14:00
# Open Price: 0.54890000
# High Price: 0.54950000
# Low Price: 0.54890000
# Close Price: 0.54950000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:15:00
# Open Price: 0.54960000
# High Price: 0.54970000
# Low Price: 0.54890000
# Close Price: 0.54930000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:16:00
# Open Price: 0.54940000
# High Price: 0.54970000
# Low Price: 0.54880000
# Close Price: 0.54890000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:17:00
# Open Price: 0.54890000
# High Price: 0.54900000
# Low Price: 0.54810000
# Close Price: 0.54820000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:18:00
# Open Price: 0.54820000
# High Price: 0.54890000
# Low Price: 0.54820000
# Close Price: 0.54890000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:19:00
# Open Price: 0.54870000
# High Price: 0.54900000
# Low Price: 0.54860000
# Close Price: 0.54880000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15

# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:48:00
# Open Price: 0.54570000
# High Price: 0.54610000
# Low Price: 0.54540000
# Close Price: 0.54570000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:49:00
# Open Price: 0.54580000
# High Price: 0.54580000
# Low Price: 0.54550000
# Close Price: 0.54550000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:50:00
# Open Price: 0.54560000
# High Price: 0.54560000
# Low Price: 0.54500000
# Close Price: 0.54530000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:51:00
# Open Price: 0.54540000
# High Price: 0.54560000
# Low Price: 0.54430000
# Close Price: 0.54470000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:52:00
# Open Price: 0.54470000
# High Price: 0.54500000
# Low Price: 0.54400000
# Close Price: 0.54420000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:53:00
# Open Price: 0.54420000
# High Price: 0.54440000
# Low Price: 0.54370000
# Close Price: 0.54440000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:54:00
# Open Price: 0.54440000
# High Price: 0.54520000
# Low Price: 0.54440000
# Close Price: 0.54510000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:55:00
# Open Price: 0.54510000
# High Price: 0.54510000
# Low Price: 0.54450000
# Close Price: 0.54450000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:56:00
# Open Price: 0.54450000
# High Price: 0.54540000
# Low Price: 0.54440000
# Close Price: 0.54510000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:57:00
# Open Price: 0.54510000
# High Price: 0.54510000
# Low Price: 0.54420000
# Close Price: 0.54470000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:58:00
# Open Price: 0.54470000
# High Price: 0.54470000
# Low Price: 0.54310000
# Close Price: 0.54350000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 15:59:00
# Open Price: 0.54350000
# High Price: 0.54370000
# Low Price: 0.54200000
# Close Price: 0.54200000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 16:00:00
# Open Price: 0.54200000
# High Price: 0.54320000
# Low Price: 0.54190000
# Close Price: 0.54290000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:02:00
# Open Price: 0.04039000
# High Price: 0.04039000
# Low Price: 0.04039000
# Close Price: 0.04039000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:03:00
# Open Price: 0.04039000
# High Price: 0.04039000
# Low Price: 0.04039000
# Close Price: 0.04039000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:04:00
# Open Price: 0.04049000
# High Price: 0.04050000
# Low Price: 0.04049000
# Close Price: 0.04050000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:05:00
# Open Price: 0.04050000
# High Price: 0.04050000
# Low Price: 0.04050000
# Close Price: 0.04050000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:06:00
# Open Price: 0.04050000
# High Price: 0.04050000
# Low Price: 0.04050000
# Close Price: 0.04050000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:07:00
# Open Price: 0.04050000
# High Price: 0.04050000
# Low Price: 0.04050000
# Close Price: 0.04050000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:08:00
# Open Price: 0.04040000
# High Price: 0.04050000
# Low Price: 0.04040000
# Close Price: 0.04050000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:09:00
# Open Price: 0.04050000
# High Price: 0.04050000
# Low Price: 0.04050000
# Close Price: 0.04050000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:10:00
# Open Price: 0.04040000
# High Price: 0.04040000
# Low Price: 0.04037000
# Close Price: 0.04037000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:11:00
# Open Price: 0.04037000
# High Price: 0.04037000
# Low Price: 0.04037000
# Close Price: 0.04037000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:12:00
# Open Price: 0.04037000
# High Price: 0.04037000
# Low Price: 0.04037000
# Close Price: 0.04037000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:13:00
# Open Price: 0.04037000
# High Price: 0.04037000
# Low Price: 0.04037000
# Close Price: 0.04037000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:14:00
# Open Price: 0.04049000
# High Price: 0.04049000
# Low Price: 0.04037000
# Close Price: 0.04037000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:15:00
# Open Price: 0.04037000
# High Price: 0.04037000
# Low Price: 0.04037000
# Close Price: 0.04037000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:16:00
# Open Price: 0.04037000
# High Price: 0.04037000
# Low Price: 0.04037000
# Close Price: 0.04037000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15

# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:45:00
# Open Price: 0.04018000
# High Price: 0.04021000
# Low Price: 0.04018000
# Close Price: 0.04021000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:46:00
# Open Price: 0.04012000
# High Price: 0.04012000
# Low Price: 0.04012000
# Close Price: 0.04012000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:47:00
# Open Price: 0.04012000
# High Price: 0.04012000
# Low Price: 0.04012000
# Close Price: 0.04012000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:48:00
# Open Price: 0.04012000
# High Price: 0.04012000
# Low Price: 0.04012000
# Close Price: 0.04012000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:49:00
# Open Price: 0.04012000
# High Price: 0.04012000
# Low Price: 0.04012000
# Close Price: 0.04012000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:50:00
# Open Price: 0.04012000
# High Price: 0.04012000
# Low Price: 0.04012000
# Close Price: 0.04012000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:51:00
# Open Price: 0.04011000
# High Price: 0.04011000
# Low Price: 0.04011000
# Close Price: 0.04011000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:52:00
# Open Price: 0.04011000
# High Price: 0.04011000
# Low Price: 0.04011000
# Close Price: 0.04011000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:53:00
# Open Price: 0.04011000
# High Price: 0.04011000
# Low Price: 0.04011000
# Close Price: 0.04011000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:54:00
# Open Price: 0.04011000
# High Price: 0.04011000
# Low Price: 0.04011000
# Close Price: 0.04011000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:55:00
# Open Price: 0.04011000
# High Price: 0.04011000
# Low Price: 0.04011000
# Close Price: 0.04011000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:56:00
# Open Price: 0.04011000
# High Price: 0.04011000
# Low Price: 0.04011000
# Close Price: 0.04011000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:57:00
# Open Price: 0.04009000
# High Price: 0.04009000
# Low Price: 0.04009000
# Close Price: 0.04009000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:58:00
# Open Price: 0.04009000
# High Price: 0.04009000
# Low Price: 0.04009000
# Close Price: 0.04009000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 15:59:00
# Open Price: 0.04009000
# High Price: 0.04009000
# Low Price: 0.04009000
# Close Price: 0.04009000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 16:00:00
# Open Price: 0.04007000
# High Price: 0.04017000
# Low Price: 0.04005000
# Close Price: 0.04006000
# ---
# Exchange: Binance
# Asset: QUICK
# Trading Pair: QUICKUSDT
# Timestamp: 2023-08-24 16:01:00
# Open Price: 0.04006000
# High Price: 0.04006000
# Low Price: 0.04006000
# Close Price: 0.04006000
# ---

# %%
def fetch_present_data_and_save(asset):
    base_url = 'https://api.binance.com/api/v3/ticker/24hr'
    trading_pair = exchange_market_lists['Binance'][asset]
    params = {'symbol': trading_pair}
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        present_data = {
            'exchange': 'Binance',
            'asset': asset,
            'trading_pair': trading_pair,
            'price': data['lastPrice'],
            'volume': data['quoteVolume'],
            'liquidity_score': None,
            'fetch_time': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }

        try:
            # Load existing data from JSON file
            with open('market_data.json', 'r') as market_data_file:
                existing_data = json.load(market_data_file)
        except (FileNotFoundError, json.JSONDecodeError):
            existing_data = []

        # Append the new present data to existing data
        existing_data.append(present_data)

        # Save the updated data to JSON file
        with open('market_data.json', 'w') as market_data_file:
            json.dump(existing_data, market_data_file, indent=4)
            print(f'{asset} present data appended to market_data.json')
    else:
        print('Error occurred. Status Code:', response.status_code)

if __name__ == '__main__':
    asset_to_fetch = 'MATIC'  # Specify the asset you want to fetch data for
    fetch_present_data_and_save(asset_to_fetch)
# Out:
# MATIC present data appended to market_data.json
