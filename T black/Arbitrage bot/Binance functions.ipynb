# %%
import requests
import json
from datetime import datetime
from exchange_markets import exchange_market_lists

def fetch_present_data_and_save(asset):
    base_url = 'https://api.binance.com/api/v3/ticker/24hr'
    trading_pair = exchange_market_lists['Binance'][asset]
    params = {'symbol': trading_pair}
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        present_data = {
            'exchange': 'Binance',
            'asset': asset,
            'trading_pair': trading_pair,
            'price': data['lastPrice'],
            'volume': data['quoteVolume'],
            'liquidity_score': None,
            'fetch_time': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }
        
        # Save the present data to JSON file
        with open('market_data.json', 'w') as market_data_file:
            json.dump(present_data, market_data_file)
            print(f'{asset} present data saved to market_data.json')
    else:
        print('Error occurred. Status Code:', response.status_code)

if __name__ == '__main__':
    asset_to_fetch = 'MATIC'  # Specify the asset you want to fetch data for
    fetch_present_data_and_save(asset_to_fetch)
    

    
#------------------------------------------------------------------------------------------------------------







def fetch_historical_data_and_save(asset):
    interval = '1m'  # 1 minute interval
    limit = 60  # Retrieve data for the past 60 minutes
    base_url = 'https://api.binance.com/api/v3/klines'
    trading_pair = exchange_market_lists['Binance'][asset]
    
    params = {
        'symbol': trading_pair,
        'interval': interval,
        'limit': limit
    }
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        historical_data = []

        for entry in data:
            timestamp = entry[0] / 1000  # Convert milliseconds to seconds
            open_price = entry[1]
            high_price = entry[2]
            low_price = entry[3]
            close_price = entry[4]

            readable_timestamp = datetime.fromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
            historical_data.append({
                'exchange': 'Binance',
                'asset': asset,
                'trading_pair': trading_pair,
                'timestamp': readable_timestamp,
                'open': open_price,
                'high': high_price,
                'low': low_price,
                'close': close_price
            })

        # Save historical data to JSON file
        with open('his_market_data.json', 'w') as his_market_data_file:
            json.dump(historical_data, his_market_data_file)
            print(f'Historical data for {asset} saved to his_market_data.json')
    else:
        print('Error occurred. Status Code:', response.status_code)

if __name__ == '__main__':
    asset_to_fetch = 'MATIC'  # Specify the asset you want to fetch data for
    fetch_historical_data_and_save(asset_to_fetch)

    
    
#---------------------------------------------------------------------------------------------------------------------
# Out:
# MATIC present data saved to market_data.json

# %%
#view data in .json files

import json

def view_json_data(file_name):
    with open(file_name, 'r') as f:
        data = json.load(f)
        return data

if __name__ == '__main__':
    market_data = view_json_data('market_data.json')
    his_market_data= view_json_data('his_market_data.json')

    print('Market Data:')
    print(json.dumps(market_data, indent=4))
# Out:
# Market Data:
# {
#     "exchange": "Binance",
#     "asset": "MATIC",
#     "trading_pair": "MATICUSDT",
#     "price": "0.55080000",
#     "volume": "36363621.49893000",
#     "liquidity_score": null,
#     "fetch_time": "2023-08-24 14:39:16"
# }

# %%
#delete data in .json files


def clear_json_file(filename):
    with open(filename, 'w') as file:
        file.write('')

# Clear market_data.json
clear_json_file('market_data.json')
print('Data in market_data.json cleared.')

# Clear his_market_data.json
clear_json_file('his_market_data.json')
print('Data in his_market_data.json cleared.')
# Out:
# Data in market_data.json cleared.
# Data in his_market_data.json cleared.

# %%
import json

# Read data from the JSON file
file_path = 'his_market_data.json'  # Replace with the actual file path
with open(file_path, 'r') as json_file:
    data = json.load(json_file)

# Print the data
for entry in data:
    print('Exchange:', entry['exchange'])
    print('Asset:', entry['asset'])
    print('Trading Pair:', entry['trading_pair'])
    print('Timestamp:', entry['timestamp'])
    print('Open Price:', entry['open'])
    print('High Price:', entry['high'])
    print('Low Price:', entry['low'])
    print('Close Price:', entry['close'])
    print('---')
# Out:
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:45:00
# Open Price: 0.55400000
# High Price: 0.55410000
# Low Price: 0.55370000
# Close Price: 0.55410000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:46:00
# Open Price: 0.55410000
# High Price: 0.55430000
# Low Price: 0.55400000
# Close Price: 0.55430000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:47:00
# Open Price: 0.55430000
# High Price: 0.55440000
# Low Price: 0.55400000
# Close Price: 0.55440000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:48:00
# Open Price: 0.55440000
# High Price: 0.55440000
# Low Price: 0.55390000
# Close Price: 0.55400000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:49:00
# Open Price: 0.55390000
# High Price: 0.55400000
# Low Price: 0.55290000
# Close Price: 0.55320000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:50:00
# Open Price: 0.55310000
# High Price: 0.55390000
# Low Price: 0.55310000
# Close Price: 0.55390000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:51:00
# Open Price: 0.55390000
# High Price: 0.55390000
# Low Price: 0.55370000
# Close Price: 0.55370000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:52:00
# Open Price: 0.55350000
# High Price: 0.55360000
# Low Price: 0.55300000
# Close Price: 0.55300000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:53:00
# Open Price: 0.55300000
# High Price: 0.55300000
# Low Price: 0.55270000
# Close Price: 0.55280000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:54:00
# Open Price: 0.55280000
# High Price: 0.55300000
# Low Price: 0.55270000
# Close Price: 0.55290000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:55:00
# Open Price: 0.55290000
# High Price: 0.55330000
# Low Price: 0.55280000
# Close Price: 0.55330000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:56:00
# Open Price: 0.55330000
# High Price: 0.55330000
# Low Price: 0.55270000
# Close Price: 0.55290000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:57:00
# Open Price: 0.55290000
# High Price: 0.55340000
# Low Price: 0.55290000
# Close Price: 0.55300000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:58:00
# Open Price: 0.55310000
# High Price: 0.55320000
# Low Price: 0.55290000
# Close Price: 0.55320000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 13:59:00
# Open Price: 0.55310000
# High Price: 0.55310000
# Low Price: 0.55280000
# Close Price: 0.55300000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:00:00
# Open Price: 0.55300000
# High Price: 0.55340000
# Low Price: 0.55280000
# Close Price: 0.55340000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:01:00
# Open Price: 0.55340000
# High Price: 0.55360000
# Low Price: 0.55330000
# Close Price: 0.55330000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:02:00
# Open Price: 0.55330000
# High Price: 0.55340000
# Low Price: 0.55320000
# Close Price: 0.55330000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:03:00
# Open Price: 0.55320000
# High Price: 0.55320000
# Low Price: 0.55300000
# Close Price: 0.55300000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:04:00
# Open Price: 0.55300000
# High Price: 0.55300000
# Low Price: 0.55230000
# Close Price: 0.55240000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:05:00
# Open Price: 0.55240000
# High Price: 0.55240000
# Low Price: 0.55210000
# Close Price: 0.55220000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:06:00
# Open Price: 0.55220000
# High Price: 0.55250000
# Low Price: 0.55210000
# Close Price: 0.55250000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:07:00
# Open Price: 0.55260000
# High Price: 0.55260000
# Low Price: 0.55210000
# Close Price: 0.55220000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:08:00
# Open Price: 0.55220000
# High Price: 0.55220000
# Low Price: 0.55180000
# Close Price: 0.55210000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:09:00
# Open Price: 0.55210000
# High Price: 0.55210000
# Low Price: 0.55170000
# Close Price: 0.55170000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:10:00
# Open Price: 0.55170000
# High Price: 0.55170000
# Low Price: 0.55080000
# Close Price: 0.55120000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:11:00
# Open Price: 0.55110000
# High Price: 0.55140000
# Low Price: 0.55110000
# Close Price: 0.55130000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:12:00
# Open Price: 0.55130000
# High Price: 0.55180000
# Low Price: 0.55110000
# Close Price: 0.55180000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:13:00
# Open Price: 0.55180000
# High Price: 0.55190000
# Low Price: 0.55170000
# Close Price: 0.55180000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:14:00
# Open Price: 0.55190000
# High Price: 0.55230000
# Low Price: 0.55190000
# Close Price: 0.55220000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:15:00
# Open Price: 0.55210000
# High Price: 0.55220000
# Low Price: 0.55190000
# Close Price: 0.55220000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:16:00
# Open Price: 0.55220000
# High Price: 0.55260000
# Low Price: 0.55220000
# Close Price: 0.55260000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:17:00
# Open Price: 0.55260000
# High Price: 0.55280000
# Low Price: 0.55240000
# Close Price: 0.55250000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:18:00
# Open Price: 0.55260000
# High Price: 0.55260000
# Low Price: 0.55210000
# Close Price: 0.55210000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:19:00
# Open Price: 0.55220000
# High Price: 0.55220000
# Low Price: 0.55200000
# Close Price: 0.55200000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:20:00
# Open Price: 0.55210000
# High Price: 0.55210000
# Low Price: 0.55160000
# Close Price: 0.55170000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:21:00
# Open Price: 0.55180000
# High Price: 0.55190000
# Low Price: 0.55150000
# Close Price: 0.55160000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:22:00
# Open Price: 0.55150000
# High Price: 0.55150000
# Low Price: 0.55070000
# Close Price: 0.55080000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:23:00
# Open Price: 0.55090000
# High Price: 0.55110000
# Low Price: 0.55080000
# Close Price: 0.55090000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:24:00
# Open Price: 0.55110000
# High Price: 0.55150000
# Low Price: 0.55100000
# Close Price: 0.55140000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:25:00
# Open Price: 0.55130000
# High Price: 0.55160000
# Low Price: 0.55120000
# Close Price: 0.55160000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:26:00
# Open Price: 0.55160000
# High Price: 0.55160000
# Low Price: 0.55120000
# Close Price: 0.55130000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:27:00
# Open Price: 0.55140000
# High Price: 0.55150000
# Low Price: 0.55120000
# Close Price: 0.55130000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:28:00
# Open Price: 0.55130000
# High Price: 0.55170000
# Low Price: 0.55130000
# Close Price: 0.55170000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:29:00
# Open Price: 0.55180000
# High Price: 0.55210000
# Low Price: 0.55160000
# Close Price: 0.55180000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:30:00
# Open Price: 0.55190000
# High Price: 0.55190000
# Low Price: 0.55150000
# Close Price: 0.55150000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:31:00
# Open Price: 0.55140000
# High Price: 0.55140000
# Low Price: 0.55070000
# Close Price: 0.55140000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:32:00
# Open Price: 0.55130000
# High Price: 0.55130000
# Low Price: 0.55070000
# Close Price: 0.55100000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:33:00
# Open Price: 0.55090000
# High Price: 0.55120000
# Low Price: 0.55030000
# Close Price: 0.55100000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:34:00
# Open Price: 0.55080000
# High Price: 0.55120000
# Low Price: 0.55080000
# Close Price: 0.55090000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:35:00
# Open Price: 0.55100000
# High Price: 0.55150000
# Low Price: 0.55100000
# Close Price: 0.55130000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:36:00
# Open Price: 0.55150000
# High Price: 0.55150000
# Low Price: 0.54980000
# Close Price: 0.55030000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:37:00
# Open Price: 0.55030000
# High Price: 0.55080000
# Low Price: 0.55020000
# Close Price: 0.55080000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:38:00
# Open Price: 0.55070000
# High Price: 0.55090000
# Low Price: 0.55070000
# Close Price: 0.55070000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:39:00
# Open Price: 0.55080000
# High Price: 0.55080000
# Low Price: 0.55040000
# Close Price: 0.55050000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:40:00
# Open Price: 0.55040000
# High Price: 0.55070000
# Low Price: 0.55020000
# Close Price: 0.55050000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:41:00
# Open Price: 0.55060000
# High Price: 0.55090000
# Low Price: 0.55010000
# Close Price: 0.55010000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:42:00
# Open Price: 0.55000000
# High Price: 0.55000000
# Low Price: 0.54910000
# Close Price: 0.54970000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:43:00
# Open Price: 0.54990000
# High Price: 0.55030000
# Low Price: 0.54970000
# Close Price: 0.54990000
# ---
# Exchange: Binance
# Asset: MATIC
# Trading Pair: MATICUSDT
# Timestamp: 2023-08-24 14:44:00
# Open Price: 0.54970000
# High Price: 0.54970000
# Low Price: 0.54970000
# Close Price: 0.54970000
# ---
